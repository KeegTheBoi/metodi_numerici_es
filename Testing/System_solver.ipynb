# %%
import numpy as np
from numpy import linalg as lin
import scipy.linalg as splin

def system_solver(A, b):
    print(f"Len → {len(A)}")
    if lin.matrix_rank(A) < A.shape[1]:
        return
    print(splin.lu(A))

def system(A, b):
    print(f"Rank → {lin.matrix_rank(A)}")
    
    # print(f"Det → {lin.det(A)}")
    # Q, R = lin.qr(A)
    # U, S, V = lin.svd(A)
    # print(lin.pinv(A))
    # print(np.zeros_like(A))
    # for i in range(len(A)):
    #     print(i)

# %%
A = np.array([[3, 4, -1], [0, -4, 5], [0, 0, 4]])
b = np.array([0, 4, 5])
system(A, b)
system_solver(A, b)
# Out:
# Rank → 3
# Len → 3
# (array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]]), array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0., -0.,  1.]]), array([[ 3.,  4., -1.],
#        [ 0., -4.,  5.],
#        [ 0.,  0.,  4.]]))
